# %% [markdown]
# **Introduction to Python 3**

# %% [markdown]
# **LETS PRINT HELLO WORLD PROGRAM**

# %%
print("Hello World ")
# Out:
# Hello World

# %% [markdown]
# **Assigning Values to Variables**

# %%
int_val = 20              # An integer number assignment
float_val   = 1.0         # A floating point number
name    = "Kshitiz"       # A string

print (int_val)
print (float_val)
print (name)
# Out:
# 20
# 1.0
# Kshitiz

# %% [markdown]
# **Multiple Assignment**
#
#
# Python allows you to assign a single value to several variables simultaneously.
#
# For example −

# %%
a = b = c = 5
print(a)
print(b)
print(c)
# Out:
# 5
# 5
# 5

# %% [markdown]
# Here, an integer object is created with the value 5, and all the three variables are assigned to the same memory location. You can also assign multiple objects to multiple variables. For example −

# %%
a, b, c = 20, 1.0, "Kshitiz"
print(a)
print(b)
print(c)
# Out:
# 20
# 1.0
# Kshitiz

# %% [markdown]
# Here, two objects with values 20 and 1.0 are assigned to the variables a and b respectively, and one string object with the value "Kshitiz" is assigned to the variable c.

# %% [markdown]
# **Standard Data Types**
#
# Python has five standard data types −
# 1.	Numbers
# 2.	String
# 3.	List
# 4.	Tuple
# 5.	Dictionary

# %% [markdown]
# **Python Numbers**
#
# Number data types store numeric values.
# Python supports three different numerical types −
#
# 1.	int (signed integers)
#
# 2.	float (floating point real values)
#
# 3.	complex (complex numbers)
#
#
# Number objects are created when you assign a value to them. For example :

# %%
num1=22
num2=4
print(num1)
print(num2)
# Out:
# 22
# 4

# %% [markdown]
# ***You can also delete the reference to a number object by using the del statement.***

# %%
del num1

# %%
num1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-d05396c398c6> in <module>()
# ----> 1 num1
#
# NameError: name 'num1' is not defined

# %% [markdown]
# **Python Strings**
#
# Strings in Python are identified as a contiguous set of characters represented in the quotation marks. Python allows either pair of single or double quotes.
#
# Subsets of strings can be taken using the slice operator ([ ] and [:] ) with indexes starting at 0 in the beginning of the string and working their way from -1 to the end.

# %%
str = 'Hello World!'

print (str)          # Prints complete string
print (str[0])       # Prints first character of the string
print (str[2:5])     # Prints characters starting from 3rd to 5th
print (str[2:])      # Prints string starting from 3rd character
print (str * 2)      # Prints string two times
print (str + "TEST") # Prints concatenated string

# %% [markdown]
# **Python Lists**
#
# Lists are the most versatile of Python's compound data types. A list contains items separated by commas and enclosed within square brackets ([]).

# %%
list = [ 'VIRUS', 78 , 2.23, 'KSHITIZ', 70.2 ]
tinylist = [123, 'Regmi']

print (list)            # Prints complete list
print (list[0])         # Prints first element of the list
print (list[1:3])       # Prints elements starting from 2nd till 3rd 
print (list[2:])        # Prints elements starting from 3rd element
print (tinylist * 2)    # Prints list two times
print (list + tinylist) # Prints concatenated lists

# %% [markdown]
# # **The list data type has some more methods. Here are all of the methods of list objects:**
#
#
#
# 1.   list.append(x) :
#
# Add an item to the end of the list.
#
# 2.  list.extend(iterable) :
#
# Extend the list by appending all the items from the iterable.
#
# 3.   list.insert(i, x) :
#
# Insert an item at a given position. The first argument is the index of the element
#  before which to insert, so a.insert(0, x) inserts at the front of the list, and                                                    a.insert(len(a), x) is equivalent to a.append(x).
#
#
# 4.   list.remove(x)
#
# Remove the first item from the list whose value is equal to x. It raises  a ValueError if there is no such item.
#
#
#
# 5.   list.sort(key=None, reverse=False)
#
# Sort the items of the list in place (the arguments can be used for sort customization, see sorted() for their explanation).
#
# 6.   list.reverse()
#
# Reverse the elements of the list in place.
#
# 7.   list.count(x)
#
# Return the number of times x appears in the list.

# %% [markdown]
# **Codes**

# %%
fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'banana']
fruits.count('apple')
# Out:
# 2

# %%
fruits.count('puumkin')
# Out:
# 0

# %%
fruits.index('banana')
# Out:
# 3

# %%
fruits.index('banana', 4)  # Find next banana starting a position 4
# Out:
# 6

# %%
fruits.reverse()

# %%
fruits
# Out:
# ['banana', 'apple', 'kiwi', 'banana', 'pear', 'apple', 'orange']

# %%
fruits.append('grape')
fruits
# Out:
# ['banana', 'apple', 'kiwi', 'banana', 'pear', 'apple', 'orange', 'grape']

# %%
fruits.sort()
fruits
# Out:
# ['apple', 'apple', 'banana', 'banana', 'grape', 'kiwi', 'orange', 'pear']

# %%
fruits.pop()
# Out:
# 'pear'

# %% [markdown]
# **Python Tuples**
#
# A tuple is another sequence data type that is similar to the list. A tuple consists of a number of values separated by commas. Unlike lists, however, tuples are enclosed within parenthesis.
#
# The main difference between lists and tuples are − Lists are enclosed in brackets ( [ ] ) and their elements and size can be changed, while tuples are enclosed in parentheses ( ( ) ) and cannot be updated. Tuples can be thought of as read-only lists. For example −

# %%
tuple = ( 'apple', 86 , 1.132, 'Kshitiz', 22.2  )
tinytuple = (12345, 'Regmi')

print (tuple)           # Prints complete tuple
print (tuple[0])        # Prints first element of the tuple
print (tuple[1:3])      # Prints elements starting from 2nd till 3rd 
print (tuple[2:])       # Prints elements starting from 3rd element
print (tinytuple * 2)   # Prints tuple two times
print (tuple + tinytuple) # Prints concatenated tuple

# %% [markdown]
# **Python Dictionary**
#
# Another useful data type built into Python is the dictionary. Dictionaries are sometimes found in other languages as “associative memories” or “associative arrays” or object in js .Python's dictionaries are kind of hash-table type.
#
# Dictionaries are enclosed by curly braces ({ }) and values can be assigned and accessed using square braces ([]).
#
# A dictionary key can be almost any Python type, but are usually numbers or strings. Values, on the other hand, can be any arbitrary Python object.
#
# It is best to think of a dictionary as a set of key: value pairs, with the requirement that the keys are unique (within one dictionary). A pair of braces creates an empty dictionary: {}. Placing a comma-separated list of key:value pairs within the braces adds initial key:value pairs to the dictionary; this is also the way dictionaries are written on output.
#
# The main operations on a dictionary are storing a value with some key and extracting the value given the key. It is also possible to delete a key:value pair with del. If you store using a key that is already in use, the old value associated with that key is forgotten. It is an error to extract a value using a non-existent key.

# %%
Dict_ex = {'name': 'Kshitiz','code':34145, 'dept': 'CSIT'}


print (Dict_ex.keys())   # Prints all the keys
print (Dict_ex.values()) # Prints all the values
# Out:
# dict_keys(['name', 'code', 'dept'])
# dict_values(['Kshitiz', 34145, 'CSIT'])

# %% [markdown]
# **Update In Dictionary**

# %%
Dict_ex['Major']='CS'
Dict_ex
# Out:
# {'Major': 'CS', 'code': 34145, 'dept': 'CSIT', 'name': 'Kshitiz'}

# %%
del Dict_ex['Major']
Dict_ex
# Out:
# {'code': 34145, 'dept': 'CSIT', 'name': 'Kshitiz'}

# %%
sorted(Dict_ex)
# Out:
# ['code', 'dept', 'name']

# %%
'Major' in Dict_ex
# Out:
# False

# %%
'name' in Dict_ex
# Out:
# True

# %% [markdown]
# # **Dictionary can  aslo be written as **

# %%
Dict_ex = dict(

    name='kshitiz',
    code=34145,
    dept= 'CSIT'


)

# %%
print (Dict_ex.keys())   # Prints all the keys
print (Dict_ex.values()) # Prints all the values
# Out:
# dict_keys(['name', 'code', 'dept'])
# dict_values(['kshitiz', 34145, 'CSIT'])

# %%
Dict_ex['Major']='CS'
Dict_ex
# Out:
# {'Major': 'CS', 'code': 34145, 'dept': 'CSIT', 'name': 'kshitiz'}

# %%
sorted(Dict_ex)
# Out:
# ['Major', 'code', 'dept', 'name']

# %%
del Dict_ex['Major']
Dict_ex
# Out:
# {'code': 34145, 'dept': 'CSIT', 'name': 'kshitiz'}

# %%
'Major' in Dict_ex
# Out:
# False

# %%
'name' in Dict_ex
# Out:
# True
